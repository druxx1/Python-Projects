# %%
import pandas as pd

tmdb = pd.read_csv('dados/tmdb_5000_movies.csv')

# %%
tmdb.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
tmdb.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %%
import seaborn as sns

sns.set_style('darkgrid')

# %%
ax = sns.histplot(tmdb['vote_average'], kde = False, bins = 50, stat = 'count')
ax.set_xlabel("Nota Media", fontsize = 12)
ax.set_ylabel("Frequencia", fontsize = 12)
ax.set_title("Media de Votos em Filmes do TMDB 5000", fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Media de Votos em Filmes do TMDB 5000')

# %%
ax = sns.boxplot(tmdb['vote_average'], orient = 'h')
ax.set_title("Distibuicao de Nota Media dos Filmes do TMDB 5000", fontsize = 18)
ax.set_xlabel("Nota Media do Filme", fontsize = 12)
# Out:
# Text(0.5, 0, 'Nota Media do Filme')

# %% [markdown]
# #

# %% [markdown]
# ## nao faz sentido filmes com nota media igual a 0 ou 10

# %%
tmdb.query('vote_average == 0')
# Out:
#        budget                                             genres  \
# 1464        0  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
# 3669        0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 3670        0                  [{"id": 10751, "name": "Family"}]
# 3852        0                      [{"id": 18, "name": "Drama"}]
# 3855  3500000                [{"id": 99, "name": "Documentary"}]
# ...       ...                                                ...
# 4769        0  [{"id": 28, "name": "Action"}, {"id": 37, "nam...
# 4771        0                     [{"id": 27, "name": "Horror"}]
# 4780        0  [{"id": 53, "name": "Thriller"}, {"id": 80, "n...
# 4785        0                      [{"id": 18, "name": "Drama"}]
# 4794        0  [{"id": 53, "name": "Thriller"}, {"id": 27, "n...
#
#                            homepage      id  \
# 1464                            NaN  310706
# 3669  http://www.romeothemovie.com/  113406
# 3670                            NaN  447027
# ...

# %%
tmdb.query('vote_average == 10')
# Out:
#       budget                                             genres homepage  \
# 3519       0                     [{"id": 35, "name": "Comedy"}]      NaN
# 4045       0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...      NaN
# 4247       1  [{"id": 10749, "name": "Romance"}, {"id": 35, ...      NaN
# 4662       0                     [{"id": 35, "name": "Comedy"}]      NaN
#
#           id                                           keywords  \
# 3519   89861  [{"id": 131, "name": "italy"}, {"id": 8250, "n...
# 4045   78373  [{"id": 1415, "name": "small town"}, {"id": 15...
# 4247  361505                                                 []
# 4662   40963        [{"id": 10183, "name": "independent film"}]
#
#      original_language         original_title  \
# 3519                en       Stiff Upper Lips
# 4045                en  Dancer, Texas Pop. 81
# 4247                en  Me You and Five Bucks
# 4662                en         Little Big Top
#
# ...

# %% [markdown]
# ## foi detectado que alguns filmes tiveram uma quantia de votos muito baixa ou ate mesmo nenhum voto, tornando-os invalidos, ou seja, nao pertenceram a analise

# %% [markdown]
# #

# %%
tmdb_mais_10_votos = tmdb.query('vote_count >= 10')

# %%
tmdb_mais_10_votos.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.392000e+03    4392.000000  4392.000000  4.392000e+03  4391.000000
# mean   3.164545e+07   49204.119991    23.448815  8.990969e+07   108.430881
# std    4.162736e+07   80136.249777    32.592158  1.682870e+08    21.014719
# min    0.000000e+00       5.000000     0.011697  0.000000e+00     0.000000
# 25%    2.895962e+06    8403.500000     6.512166  1.365700e+04    95.000000
# 50%    1.700000e+07   13084.500000    14.827784  2.685837e+07   105.000000
# 75%    4.200000e+07   46831.250000    30.258282  1.022818e+08   118.500000
# max    3.800000e+08  417859.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4392.000000   4392.000000
# mean       6.226935    754.441712
# std        0.893215   1272.263761
# min        1.900000     10.000000
# 25%        5.700000     83.750000
# 50%        6.300000    288.500000
# 75%        6.800000    831.000000
# ...

# %%
ax = sns.histplot(tmdb_mais_10_votos['vote_average'], kde = True, bins = 50, stat = 'count')
ax.set_xlabel("Nota Media", fontsize = 12)
ax.set_ylabel("Frequencia", fontsize = 12)
ax.set_title("Media de Votos em Filmes com Mais ou 10 Votos do TMDB 5000", fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Media de Votos em Filmes com Mais ou 10 Votos do TMDB 5000')

# %%
ax = sns.histplot(tmdb_mais_10_votos['vote_average'], kde = True, cumulative = True, bins = 50, stat = 'density')
ax.set_xlabel("Nota Media", fontsize = 12)
ax.set_ylabel("Frequencia", fontsize = 12)
ax.set_title("Media de Votos em Filmes com Mais ou 10 Votos do TMDB 5000", fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Media de Votos em Filmes com Mais ou 10 Votos do TMDB 5000')

# %%
ax = sns.boxplot(tmdb_mais_10_votos['vote_average'], orient = 'h')
ax.set_title("Distibuicao de Nota Media dos Filmes do TMDB 5000", fontsize = 18)
ax.set_xlabel("Nota Media do Filme", fontsize = 12)
# Out:
# Text(0.5, 0, 'Nota Media do Filme')

# %%
notas = pd.read_csv('dados/ratings.csv')

# %%
notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
nota_media = notas.groupby('movieId').mean()['rating']

# %%
nota_media.head(10)
# Out:
# movieId
# 1     3.920930
# 2     3.431818
# 3     3.259615
# 4     2.357143
# 5     3.071429
# 6     3.946078
# 7     3.185185
# 8     2.875000
# 9     3.125000
# 10    3.496212
# Name: rating, dtype: float64

# %%
ax = sns.histplot(nota_media.values, kde = True, bins = 40, stat = 'density')
ax.set_xlabel("Nota Media", fontsize = 12)
ax.set_ylabel("Densidade", fontsize = 12)
ax.set_title("Media de Votos em Filmes do TMDB 5000", fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Media de Votos em Filmes do TMDB 5000')

# %%
qntd_votos_por_filme = notas.groupby('movieId').count()
filmes_10_votos = qntd_votos_por_filme.query('rating >= 10').index
filmes_10_votos.values
# Out:
# array([     1,      2,      3, ..., 177765, 179819, 187593], dtype=int64)

# %%
nota_media_10_votos = nota_media.loc[filmes_10_votos.values]
nota_media_10_votos
# Out:
# movieId
# 1         3.920930
# 2         3.431818
# 3         3.259615
# 5         3.071429
# 6         3.946078
#             ...
# 174055    3.423077
# 176371    3.805556
# 177765    3.538462
# 179819    3.125000
# 187593    3.875000
# Name: rating, Length: 2269, dtype: float64

# %%
ax = sns.histplot(nota_media_10_votos, kde = True, bins = 30, stat = 'density')
ax.set_xlabel("Nota Media", fontsize = 12)
ax.set_ylabel("Densidade", fontsize = 12)
ax.set_title("Media de Votos em Filmes do TMDB 5000", fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Media de Votos em Filmes do TMDB 5000')

# %%
ax = sns.boxplot(nota_media_10_votos.values, orient = 'h')
ax.set_title("Distibuicao de Nota Media dos Filmes do TMDB 5000", fontsize = 18)
ax.set_xlabel("Nota Media do Filme", fontsize = 12)
# Out:
# Text(0.5, 0, 'Nota Media do Filme')

# %%
ax = sns.histplot(nota_media_10_votos, kde = True, cumulative = True, bins = 30, stat = 'density')
ax.set_xlabel("Nota Media", fontsize = 12)
ax.set_ylabel("% Acumulada de Filmes", fontsize = 12)
ax.set_title("Media de Votos em Filmes do TMDB 5000", fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Media de Votos em Filmes do TMDB 5000')

# %%
tmdb_mais_10_votos['vote_count']
# Out:
# 0       11800
# 1        4500
# 2        4466
# 3        9106
# 4        2124
#         ...
# 4790       17
# 4792       63
# 4796      658
# 4798      238
# 4802       16
# Name: vote_count, Length: 4392, dtype: int64

# %%
ax = sns.histplot(tmdb_mais_10_votos['vote_count'], kde = True, bins = 50, stat = 'density')
ax.set_xlabel("Numero de Votos", fontsize = 12)
ax.set_ylabel("Densidade", fontsize = 12)
ax.set_title("Numero de Votos em Filmes com Mais ou 10 Votos do TMDB 5000", fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Numero de Votos em Filmes com Mais ou 10 Votos do TMDB 5000')

# %%
tmdb_budget_maior_zero = tmdb.query('budget > 0')['budget']
tmdb_budget_maior_zero
# Out:
# 0       237000000
# 1       300000000
# 2       245000000
# 3       250000000
# 4       260000000
#           ...
# 4791           13
# 4792        20000
# 4796         7000
# 4798       220000
# 4799         9000
# Name: budget, Length: 3766, dtype: int64

# %%
ax = sns.histplot(tmdb_budget_maior_zero.values, kde = True, bins = 50, stat = 'density')
ax.set_xlabel("Budget (gasto)", fontsize = 12)
ax.set_ylabel("Densidade", fontsize = 12)
ax.set_title("Gastos em Filmes do TMDB 5000", fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Gastos em Filmes do TMDB 5000')

# %%
ax = sns.histplot(tmdb['popularity'], kde = True, bins = 50, stat = 'density')
ax.set_xlabel("popularidade", fontsize = 12)
ax.set_ylabel("Densidade", fontsize = 12)
ax.set_title("Popularidade de Filmes do TMDB 5000", fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Popularidade de Filmes do TMDB 5000')

# %%
ax = sns.histplot(tmdb['runtime'], kde = True, bins = 50, stat = 'density')
ax.set_xlabel("Tempo de Duracao", fontsize = 12)
ax.set_ylabel("Densidade", fontsize = 12)
ax.set_title("Duracao de Filmes do TMDB 5000", fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Duracao de Filmes do TMDB 5000')

# %%
tmdb['runtime'].isnull().value_counts()
# Out:
# runtime
# False    4801
# True        2
# Name: count, dtype: int64

# %%
tmdb['runtime'].dropna()
# Out:
# 0       162.0
# 1       169.0
# 2       148.0
# 3       165.0
# 4       132.0
#         ...
# 4798     81.0
# 4799     85.0
# 4800    120.0
# 4801     98.0
# 4802     90.0
# Name: runtime, Length: 4801, dtype: float64

# %%
tmdb.query('runtime == 0')
# Out:
#        budget                                             genres  \
# 1011        0                     [{"id": 27, "name": "Horror"}]
# 3112        0  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
# 3669        0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 3809  4000000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 3953        0  [{"id": 10752, "name": "War"}, {"id": 18, "nam...
# 3992        0                                                 []
# 4068        0                                                 []
# 4118        0                                                 []
# 4205        0  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
# 4210        0                 [{"id": 10749, "name": "Romance"}]
# 4241  1500000                     [{"id": 35, "name": "Comedy"}]
# 4313        0  [{"id": 53, "name": "Thriller"}, {"id": 27, "n...
# 4318        0                     [{"id": 27, "name": "Horror"}]
# ...

# %%
ax = sns.histplot(tmdb.query('runtime > 0')['runtime'].dropna(), kde = True, bins = 50, stat = 'density')
ax.set_xlabel("Tempo de Duracao", fontsize = 12)
ax.set_ylabel("Densidade", fontsize = 12)
ax.set_title("Duracao de Filmes do TMDB 5000", fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Duracao de Filmes do TMDB 5000')

# %%
ax = sns.histplot(tmdb.query('runtime > 0')['runtime'].dropna(), kde = True, bins = 50, stat = 'density', cumulative = True)
ax.set_xlabel("Tempo de Duracao", fontsize = 12)
ax.set_ylabel("% de Filmes", fontsize = 12)
ax.set_title("Duracao de Filmes do TMDB 5000", fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Duracao de Filmes do TMDB 5000')

# %%
tmdb.query('runtime > 0')['runtime'].dropna().quantile(0.8)
# Out:
# 121.0

# %%
print("Media dos filmes com pelo menos 10 votos (Movielens): {}".format(nota_media_10_votos.mean()))
# Out:
# Media dos filmes com pelo menos 10 votos (Movielens): 3.4320503405352594

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

medias = list()

np.random.seed(75243)
temp = nota_media_10_votos.sample(frac = 1)

for i in range(1, len(temp)):
    medias.append(temp[0:i].mean())
    
# OU, DA MANEIRA ABAIXO FUNCIONA DE MESMA FORMA 
# medias = [temp[0:i].mean() for i in range(1, len(temp))]

plt.plot(medias)

# %%
len(nota_media_10_votos)
# Out:
# 2269

# %%
from statsmodels.stats.weightstats import zconfint

zconfint(nota_media_10_votos)
# Out:
# (3.4112459477469557, 3.452854733323563)

# %%
from statsmodels.stats.weightstats import DescrStatsW

descr_todos_com_10_votos = DescrStatsW(nota_media_10_votos)
descr_todos_com_10_votos.tconfint_mean()
# Out:
# (3.41123483922938, 3.4528658418411386)

# %%
filmes = pd.read_csv('dados/movies.csv')
filmes.query('movieId == 1')
# Out:
#    movieId             title                                       genres
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy

# %%
notas1 = notas.query('movieId == 1')
notas1.head()
# Out:
#       userId  movieId  rating   timestamp
# 0          1        1     4.0   964982703
# 516        5        1     4.0   847434962
# 874        7        1     4.5  1106635946
# 1434      15        1     2.5  1510577970
# 1667      17        1     4.5  1305696483

# %%
ax = sns.histplot(notas1['rating'], kde = True, stat = 'density')
ax.set_xlabel("Nota", fontsize = 12)
ax.set_ylabel("Densidade", fontsize = 12)
ax.set_title("Distribuicao de Notas para o Toy Story", fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Distribuicao de Notas para o Toy Story')

# %%
ax = sns.boxplot(notas1['rating'], orient = 'h')
ax.set_xlabel("Nota", fontsize = 12)
ax.set_title("Distribuicao de Notas para o Toy Story", fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Distribuicao de Notas para o Toy Story')

# %%
notas1['rating'].mean()
# Out:
# 3.9209302325581397

# %%
notas1['rating'].count()
# Out:
# 215

# %%
zconfint(notas1['rating'])
# Out:
# (3.8093359183563402, 4.032524546759939)

# %%
from statsmodels.stats.weightstats import ztest

ztest(notas1['rating'], value = 3.4320503405352594)
# Out:
# (8.586342305916732, 8.978190401885648e-18)

# %%
temp = notas1.sample(frac = 1)['rating']
medias = list()
np.random.seed(75241)

def calcula_teste(i):
    media = (temp[0:i].mean())
    stat, p = ztest(temp[0:i], value = 3.4320503405352594)
    return(i, media, p)

valores = np.array([calcula_teste(i) for i in range(2, len(temp))])

# for i in range(1, len(temp)):
#     medias.append(calcula_teste(i))
    
plt.plot(valores[:,0], valores[:,1])
plt.plot(valores[:,0], valores[:,2], color = 'green')
plt.hlines(y = 0.05, xmin = 2, xmax = len(temp), linestyle = '--', color = 'red')
# medias

# %%
zconfint(notas1['rating'], notas['rating'])
# Out:
# (0.2799245129192442, 0.5588219849631111)

# %%
from scipy.stats import ttest_ind

ttest_ind(notas1['rating'], notas['rating'])
# Out:
# TtestResult(statistic=5.894327101501841, pvalue=3.774003138720876e-09, df=101049.0)

# %%
descr_todas_notas = DescrStatsW(notas['rating'])
descr_toystory = DescrStatsW(notas1['rating'])
comparacao = descr_todas_notas.get_compare(descr_toystory)
comparacao.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
comparacao.summary(use_t = True)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
cores = ['pink', 'lightblue']

box = plt.boxplot([notas['rating'], notas1['rating']], labels = ["Todas as Notas", "Toy Story"], patch_artist = True)
plt.title("Distribuicao de Notas de Acordo com Filmes", fontsize = 15)

for caixa, cor in zip(box['boxes'], cores):
    caixa.set(color = cor)

# %%
cores = ['pink', 'lightblue']

box = plt.boxplot([notas['rating'], notas1[3:12]['rating']], labels = ["Todas as Notas", "Toy Story"], patch_artist = True)
plt.title("Distribuicao de Notas de Acordo com Filmes", fontsize = 15)

for caixa, cor in zip(box['boxes'], cores):
    caixa.set(color = cor)

# %%
descr_todas_notas = DescrStatsW(notas['rating'])
descr_toystory = DescrStatsW(notas1[3:12]['rating'])
comparacao = descr_todas_notas.get_compare(descr_toystory)
comparacao.summary(use_t = True)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
filmes.query('movieId in [1, 593, 72226]')
# Out:
#       movieId                             title  \
# 0           1                  Toy Story (1995)
# 510       593  Silence of the Lambs, The (1991)
# 7180    72226          Fantastic Mr. Fox (2009)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 510                         Crime|Horror|Thriller
# 7180    Adventure|Animation|Children|Comedy|Crime

# %%
notas593 = notas.query('movieId == 593')
notas72226 = notas.query('movieId == 72226')

cores = ['midnightblue', 'indigo', 'plum']

box = plt.boxplot([notas1['rating'], notas593['rating'], notas72226['rating']], patch_artist = True,
                  labels = ["Toy Story", "Silence of the Lambs", "Fantastic Mr. Fox"])
plt.title("Comparando as Notas Entre os Filmes de ID 1, 593 e 72226", fontsize = 13.5)
plt.ylabel("Notas")

for caixa, cor in zip(box['boxes'], cores):
    caixa.set(color = cor)

# %%
sns.boxplot(x = 'movieId', y = 'rating', data = notas.query('movieId in [1, 593, 72226]'))
# Out:
# <Axes: xlabel='movieId', ylabel='rating'>

# %%
descr_1 = DescrStatsW(notas1['rating'])
descr_72226 = DescrStatsW(notas72226['rating'])
descr_593 = DescrStatsW(notas593['rating'])


comparacao = descr_1.get_compare(descr_593)
comparacao.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
comparacao = descr_1.get_compare(descr_72226)
comparacao.summary(use_t = True)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
comparacao = descr_593.get_compare(descr_72226)
comparacao.summary(use_t = True)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
notas.query('movieId in [1, 593, 72226]').groupby('movieId').count()
# Out:
#          userId  rating  timestamp
# movieId
# 1           215     215        215
# 593         279     279        279
# 72226        18      18         18

# %%
from scipy.stats import normaltest

_, p = normaltest(notas1['rating'])
p
# Out:
# 0.00011053430732728716

# %%
from scipy.stats import ranksums

ranksums(notas1['rating'], notas593['rating'])
# Out:
# RanksumsResult(statistic=-3.5930962013771377, pvalue=0.0003267718756440693)
